# %%
# Dummy PLARF-like base locations (approximate)
bases = [
    {"name": "Base A – Fujian coast", "lat": 25.9, "lon": 119.3},
    {"name": "Base B – Shanghai area", "lat": 31.2, "lon": 121.5},
    {"name": "Base C – Guangzhou area", "lat": 23.1, "lon": 113.3},
    {"name": "Base D – Inland (Xi'an)", "lat": 34.3, "lon": 108.9},
]

bases
# Out:
# [{'name': 'Base A – Fujian coast', 'lat': 25.9, 'lon': 119.3},
#  {'name': 'Base B – Shanghai area', 'lat': 31.2, 'lon': 121.5},
#  {'name': 'Base C – Guangzhou area', 'lat': 23.1, 'lon': 113.3},
#  {'name': "Base D – Inland (Xi'an)", 'lat': 34.3, 'lon': 108.9}]

# %%
# Simplified missile ranges in kilometers
ranges_km = [
    {"label": "SRBM ~300 km", "radius_km": 300, "color": "red"},
    {"label": "MRBM ~1500 km", "radius_km": 1500, "color": "blue"},
]

ranges_km
# Out:
# [{'label': 'SRBM ~300 km', 'radius_km': 300, 'color': 'red'},
#  {'label': 'MRBM ~1500 km', 'radius_km': 1500, 'color': 'blue'}]

# %%
import folium

# Center the map over eastern China
m = folium.Map(location=[30, 115], zoom_start=4)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_73dfd875362f4a3c028ccf194d19e8bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_73dfd875362f4a3c028ccf194d19e8bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_73dfd875362f4a3c028ccf194d19e8bb = L.map(
#                 &quot;map_73dfd875362f4a3c028ccf194d19e8bb&quot;,
#                 {
#                     center: [30.0, 115.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_efcbc47d28b34ba51d8b2f81e8a7a870 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_efcbc47d28b34ba51d8b2f81e8a7a870.addTo(map_73dfd875362f4a3c028ccf194d19e8bb);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Add base markers and range circles
for base in bases:
    # 1. Marker for the base
    folium.Marker(
        location=[base["lat"], base["lon"]],
        popup=base["name"],
        tooltip=base["name"],
    ).add_to(m)

    # 2. Range circles for each missile type
    for r in ranges_km:
        folium.Circle(
            location=[base["lat"], base["lon"]],
            radius=r["radius_km"] * 1000,  # km → meters
            popup=f'{base["name"]} – {r["label"]}',
            color=r["color"],
            fill=True,
            fill_opacity=0.08,
        ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_73dfd875362f4a3c028ccf194d19e8bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_73dfd875362f4a3c028ccf194d19e8bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_73dfd875362f4a3c028ccf194d19e8bb = L.map(
#                 &quot;map_73dfd875362f4a3c028ccf194d19e8bb&quot;,
#                 {
#                     center: [30.0, 115.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_efcbc47d28b34ba51d8b2f81e8a7a870 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_efcbc47d28b34ba51d8b2f81e8a7a870.addTo(map_73dfd875362f4a3c028ccf194d19e8bb);
#
#
#             tile_layer_efcbc47d28b34ba51d8b2f81e8a7a870.addTo(map_73dfd875362f4a3c028ccf194d19e8bb);
#
#
#             var marker_6caa8372fa1c072bedd5ff5bea9736e0 = L.marker(
#                 [25.9, 119.3],
#                 {
# }
#             ).addTo(map_73dfd875362f4a3c028ccf194d19e8bb);
#
#
#         var popup_aeb46c7b51da3e21b79634259c036893 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f658d8d5114bdc969564def6c87256c = $(`&lt;div id=&quot;html_9f658d8d5114bdc969564def6c87256c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Base A – Fujian coast&lt;/div&gt;`)[0];
#                 popup_aeb46c7b51da3e21b79634259c036893.setContent(html_9f658d8d5114bdc969564def6c87256c);
#
#
#
#         marker_6caa8372fa1c072bedd5ff5bea9736e0.bindPopup(popup_aeb46c7b51da3e21b79634259c036893)
#         ;
#
#
#
#
#             marker_6caa8372fa1c072bedd5ff5bea9736e0.bindTooltip(
#                 `&lt;div&gt;
#                      Base A – Fujian coast
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_5631293535fb82801699e5402b457b03 = L.circle(
#                 [25.9, 119.3],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.08, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 300000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_73dfd875362f4a3c028ccf194d19e8bb);
#
#
#         var popup_b829656bf6322a2d57ce48b82c4b8961 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e24e0b9ea468b4f3692f2a3b12f692dd = $(`&lt;div id=&quot;html_e24e0b9ea468b4f3692f2a3b12f692dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Base A – Fujian coast – SRBM ~300 km&lt;/div&gt;`)[0];
#                 popup_b829656bf6322a2d57ce48b82c4b8961.setContent(html_e24e0b9ea468b4f3692f2a3b12f692dd);
#
#
#
#         circle_5631293535fb82801699e5402b457b03.bindPopup(popup_b829656bf6322a2d57ce48b82c4b8961)
#         ;
#
#
#
#
#             var circle_41ddc9bb9c730b66b74d8322fd661a4f = L.circle(
#                 [25.9, 119.3],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.08, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1500000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_73dfd875362f4a3c028ccf194d19e8bb);
#
#
#         var popup_d9696634c762625896f60da9362fcbe5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4810c23d677fd4a158b076693d3dd32c = $(`&lt;div id=&quot;html_4810c23d677fd4a158b076693d3dd32c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Base A – Fujian coast – MRBM ~1500 km&lt;/div&gt;`)[0];
#                 popup_d9696634c762625896f60da9362fcbe5.setContent(html_4810c23d677fd4a158b076693d3dd32c);
#
#
#
#         circle_41ddc9bb9c730b66b74d8322fd661a4f.bindPopup(popup_d9696634c762625896f60da9362fcbe5)
#         ;
#
#
#
#
#             var marker_63a404929a6bbf39bc9a71af6da01884 = L.marker(
#                 [31.2, 121.5],
#                 {
# }
#             ).addTo(map_73dfd875362f4a3c028ccf194d19e8bb);
