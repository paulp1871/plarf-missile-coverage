# %%
import pandas as pd
bases = pd.read_csv("../data/bases.csv")
ranges = pd.read_csv("../data/ranges.csv")

bases, ranges
# Out:
# (                      name   lat    lon
#  0    Base A – Fujian coast  25.9  119.3
#  1   Base B - Shanghai area  31.2  121.5
#  2  Base C - Guangzhou area  23.1  113.3
#  3  Base D - Inland (Xi'an)  34.3  108.9,
#             label category  radius_km color
#  0   SRBM ~300 km     SRBM        300   red
#  1  MRBM ~1500 km     MRBM       1500  blue)

# %%
import folium
m = folium.Map(location=[30, 115], zoom_start=4)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae3276a69c48c5c3673d121127f3aaa4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae3276a69c48c5c3673d121127f3aaa4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae3276a69c48c5c3673d121127f3aaa4 = L.map(
#                 &quot;map_ae3276a69c48c5c3673d121127f3aaa4&quot;,
#                 {
#                     center: [30.0, 115.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e225dd14230633919553f54225f5f41f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e225dd14230633919553f54225f5f41f.addTo(map_ae3276a69c48c5c3673d121127f3aaa4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Create feature groups for each missile category
srbm_layer = folium.FeatureGroup(name="SRBM coverage")
mrbm_layer = folium.FeatureGroup(name="MRBM coverage")

# Add base markers
for _, base in bases.iterrows():
    folium.Marker(
        location=[base["lat"], base["lon"]],
        popup=base["name"],
        tooltip=base["name"],
    ).add_to(m)

# %%
for _, base in bases.iterrows():
    for _, r in ranges.iterrows():
        circle = folium.Circle(
            location=[base["lat"], base["lon"]],
            radius=r["radius_km"] * 1000,  # km -> m
            popup=f'{base["name"]} – {r["label"]}',
            color=r["color"],
            fill=True,
            fill_opacity=0.08,
        )

        # Add to the correct layer based on category
        if r["category"] == "SRBM":
            circle.add_to(srbm_layer)
        elif r["category"] == "MRBM":
            circle.add_to(mrbm_layer)

# %%
# Add the layers to the map
srbm_layer.add_to(m)
mrbm_layer.add_to(m)

# Add a layer control toggle (top-right of the map)
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae3276a69c48c5c3673d121127f3aaa4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae3276a69c48c5c3673d121127f3aaa4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae3276a69c48c5c3673d121127f3aaa4 = L.map(
#                 &quot;map_ae3276a69c48c5c3673d121127f3aaa4&quot;,
#                 {
#                     center: [30.0, 115.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e225dd14230633919553f54225f5f41f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e225dd14230633919553f54225f5f41f.addTo(map_ae3276a69c48c5c3673d121127f3aaa4);
#
#
#             tile_layer_e225dd14230633919553f54225f5f41f.addTo(map_ae3276a69c48c5c3673d121127f3aaa4);
#
#
#             var marker_69bf869673fe69d84483eddba1cc0152 = L.marker(
#                 [25.9, 119.3],
#                 {
# }
#             ).addTo(map_ae3276a69c48c5c3673d121127f3aaa4);
#
#
#         var popup_db55f7d96b4cf38da474c11ae6d485b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d778fc2cf9440b82439c27be9952f18 = $(`&lt;div id=&quot;html_4d778fc2cf9440b82439c27be9952f18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Base A – Fujian coast&lt;/div&gt;`)[0];
#                 popup_db55f7d96b4cf38da474c11ae6d485b0.setContent(html_4d778fc2cf9440b82439c27be9952f18);
#
#
#
#         marker_69bf869673fe69d84483eddba1cc0152.bindPopup(popup_db55f7d96b4cf38da474c11ae6d485b0)
#         ;
#
#
#
#
#             marker_69bf869673fe69d84483eddba1cc0152.bindTooltip(
#                 `&lt;div&gt;
#                      Base A – Fujian coast
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_1bf9664b0f0c82d3a933b0a5a4387211 = L.marker(
#                 [31.2, 121.5],
#                 {
# }
#             ).addTo(map_ae3276a69c48c5c3673d121127f3aaa4);
#
#
#         var popup_6c177262cac0c2eb9ec96d1fe769e4c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba0725b4250f1d4826b1860d9eadcbc8 = $(`&lt;div id=&quot;html_ba0725b4250f1d4826b1860d9eadcbc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Base B - Shanghai area&lt;/div&gt;`)[0];
#                 popup_6c177262cac0c2eb9ec96d1fe769e4c7.setContent(html_ba0725b4250f1d4826b1860d9eadcbc8);
#
#
#
#         marker_1bf9664b0f0c82d3a933b0a5a4387211.bindPopup(popup_6c177262cac0c2eb9ec96d1fe769e4c7)
#         ;
#
#
#
#
#             marker_1bf9664b0f0c82d3a933b0a5a4387211.bindTooltip(
#                 `&lt;div&gt;
#                      Base B - Shanghai area
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_2a34d4b9378774b5bb57cea7874f5eab = L.marker(
#                 [23.1, 113.3],
#                 {
# }
#             ).addTo(map_ae3276a69c48c5c3673d121127f3aaa4);
#
#
#         var popup_7f64d3fb9a18bbe62649bbab146b79b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff81d067e7a5e48c29cee05768e7ef52 = $(`&lt;div id=&quot;html_ff81d067e7a5e48c29cee05768e7ef52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Base C - Guangzhou area&lt;/div&gt;`)[0];
#                 popup_7f64d3fb9a18bbe62649bbab146b79b1.setContent(html_ff81d067e7a5e48c29cee05768e7ef52);
#
#
#
#         marker_2a34d4b9378774b5bb57cea7874f5eab.bindPopup(popup_7f64d3fb9a18bbe62649bbab146b79b1)
#         ;
#
#
#
#
#             marker_2a34d4b9378774b5bb57cea7874f5eab.bindTooltip(
#                 `&lt;div&gt;
#                      Base C - Guangzhou area
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_4e214cba2879c90bb8e74d427134abf4 = L.marker(
#                 [34.3, 108.9],
#                 {
# }
#             ).addTo(map_ae3276a69c48c5c3673d121127f3aaa4);
#
#
#         var popup_a0d9524cef9dde34d89e71e8d85c7f50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9d7f46c185550b1acd0a9e635e8a691 = $(`&lt;div id=&quot;html_c9d7f46c185550b1acd0a9e635e8a691&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Base D - Inland (Xi&#x27;an)&lt;/div&gt;`)[0];
#                 popup_a0d9524cef9dde34d89e71e8d85c7f50.setContent(html_c9d7f46c185550b1acd0

# %%
# Export the map to an HTML file
output_path = "../output/plarf_srbm_mrbm_map.html"
m.save(output_path)

output_path
# Out:
# '../output/plarf_srbm_mrbm_map.html'
