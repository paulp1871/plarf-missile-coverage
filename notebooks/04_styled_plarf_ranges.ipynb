# %%
import pandas as pd
bases = pd.read_csv("../data/bases.csv")
ranges = pd.read_csv("../data/ranges.csv")

bases, ranges
# Out:
# (                      name   lat    lon
#  0    Base A – Fujian coast  25.9  119.3
#  1   Base B - Shanghai area  31.2  121.5
#  2  Base C - Guangzhou area  23.1  113.3
#  3  Base D - Inland (Xi'an)  34.3  108.9,
#             label category  radius_km color
#  0   SRBM ~300 km     SRBM        300   red
#  1  MRBM ~1500 km     MRBM       1500  blue)

# %%
import folium
m = folium.Map(location=[30, 115], zoom_start=4)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dc10546d2dc60a89c34b3437c1c8f56b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dc10546d2dc60a89c34b3437c1c8f56b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dc10546d2dc60a89c34b3437c1c8f56b = L.map(
#                 &quot;map_dc10546d2dc60a89c34b3437c1c8f56b&quot;,
#                 {
#                     center: [30.0, 115.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b973af235ee51cd6937259e7f71f2bd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2b973af235ee51cd6937259e7f71f2bd.addTo(map_dc10546d2dc60a89c34b3437c1c8f56b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Create feature groups for each missile category
srbm_layer = folium.FeatureGroup(name="SRBM coverage")
mrbm_layer = folium.FeatureGroup(name="MRBM coverage")

# Add base markers
for _, base in bases.iterrows():
    folium.Marker(
        location=[base["lat"], base["lon"]],
        popup=base["name"],
        tooltip=base["name"],
    ).add_to(m)

# %%
for _, base in bases.iterrows():
    for _, r in ranges.iterrows():
        circle = folium.Circle(
            location=[base["lat"], base["lon"]],
            radius=r["radius_km"] * 1000,  # km -> m
            popup=f'{base["name"]} – {r["label"]}',
            color=r["color"],
            fill=True,
            fill_opacity=0.08,
        )

        # Add to the correct layer based on category
        if r["category"] == "SRBM":
            circle.add_to(srbm_layer)
        elif r["category"] == "MRBM":
            circle.add_to(mrbm_layer)

# %%
# Add the layers to the map
srbm_layer.add_to(m)
mrbm_layer.add_to(m)

# Add a layer control toggle (top-right of the map)
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dc10546d2dc60a89c34b3437c1c8f56b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dc10546d2dc60a89c34b3437c1c8f56b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dc10546d2dc60a89c34b3437c1c8f56b = L.map(
#                 &quot;map_dc10546d2dc60a89c34b3437c1c8f56b&quot;,
#                 {
#                     center: [30.0, 115.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b973af235ee51cd6937259e7f71f2bd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2b973af235ee51cd6937259e7f71f2bd.addTo(map_dc10546d2dc60a89c34b3437c1c8f56b);
#
#
#             tile_layer_2b973af235ee51cd6937259e7f71f2bd.addTo(map_dc10546d2dc60a89c34b3437c1c8f56b);
#
#
#             var marker_dde97404a3b17e8f5e4227c1f7bf43a8 = L.marker(
#                 [25.9, 119.3],
#                 {
# }
#             ).addTo(map_dc10546d2dc60a89c34b3437c1c8f56b);
#
#
#         var popup_67415548d1ada2db049e578576f4dffa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df3cfb4a0d06b2c407c9947fb29e5641 = $(`&lt;div id=&quot;html_df3cfb4a0d06b2c407c9947fb29e5641&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Base A – Fujian coast&lt;/div&gt;`)[0];
#                 popup_67415548d1ada2db049e578576f4dffa.setContent(html_df3cfb4a0d06b2c407c9947fb29e5641);
#
#
#
#         marker_dde97404a3b17e8f5e4227c1f7bf43a8.bindPopup(popup_67415548d1ada2db049e578576f4dffa)
#         ;
#
#
#
#
#             marker_dde97404a3b17e8f5e4227c1f7bf43a8.bindTooltip(
#                 `&lt;div&gt;
#                      Base A – Fujian coast
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_3668726b7cd9df071f39567e5cc778ac = L.marker(
#                 [31.2, 121.5],
#                 {
# }
#             ).addTo(map_dc10546d2dc60a89c34b3437c1c8f56b);
#
#
#         var popup_a2b928cb7e32f92591090ca0cf2fcb9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_894b73798ee06b9f9c8c5a02d7262fd1 = $(`&lt;div id=&quot;html_894b73798ee06b9f9c8c5a02d7262fd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Base B - Shanghai area&lt;/div&gt;`)[0];
#                 popup_a2b928cb7e32f92591090ca0cf2fcb9b.setContent(html_894b73798ee06b9f9c8c5a02d7262fd1);
#
#
#
#         marker_3668726b7cd9df071f39567e5cc778ac.bindPopup(popup_a2b928cb7e32f92591090ca0cf2fcb9b)
#         ;
#
#
#
#
#             marker_3668726b7cd9df071f39567e5cc778ac.bindTooltip(
#                 `&lt;div&gt;
#                      Base B - Shanghai area
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_92c1ddd97ec9d665590ef0b3e319a074 = L.marker(
#                 [23.1, 113.3],
#                 {
# }
#             ).addTo(map_dc10546d2dc60a89c34b3437c1c8f56b);
#
#
#         var popup_5ffa5a04e621725b3f6fb5fd3cb91500 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5285d352212b60ef62b69a5905781d9 = $(`&lt;div id=&quot;html_d5285d352212b60ef62b69a5905781d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Base C - Guangzhou area&lt;/div&gt;`)[0];
#                 popup_5ffa5a04e621725b3f6fb5fd3cb91500.setContent(html_d5285d352212b60ef62b69a5905781d9);
#
#
#
#         marker_92c1ddd97ec9d665590ef0b3e319a074.bindPopup(popup_5ffa5a04e621725b3f6fb5fd3cb91500)
#         ;
#
#
#
#
#             marker_92c1ddd97ec9d665590ef0b3e319a074.bindTooltip(
#                 `&lt;div&gt;
#                      Base C - Guangzhou area
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_430b8f4d7c9440aff040b7c0169f654a = L.marker(
#                 [34.3, 108.9],
#                 {
# }
#             ).addTo(map_dc10546d2dc60a89c34b3437c1c8f56b);
#
#
#         var popup_406db61d892b3d949ad9f2b5a7eb91f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9bb9b8f502b6535cbcd7e0e43c656224 = $(`&lt;div id=&quot;html_9bb9b8f502b6535cbcd7e0e43c656224&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Base D - Inland (Xi&#x27;an)&lt;/div&gt;`)[0];
#                 popup_406db61d892b3d949ad9f2b5a7eb91f0.setContent(html_9bb9b8f502b6535cbcd7
