# %%
import os
import sys
from pathlib import Path

# Ensure the repository root (and src package) are on sys.path
PROJECT_ROOT = Path().resolve().parent
SRC_DIR = PROJECT_ROOT / "src"

for candidate in (PROJECT_ROOT, SRC_DIR):
    candidate_str = str(candidate)
    if candidate_str not in sys.path:
        sys.path.insert(0, candidate_str)

from src.missile_map import (
    load_bases,
    load_ranges,
    create_map,
    add_range_layers,
    add_legend,
    export_map,
    build_plarf_map,
)

# %%
m = build_plarf_map(
    output_path="../output/plarf_missile_coverage.html"
)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe909c7217555fd57dc5800c83930cc2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;
#         position: fixed;
#         bottom: 50px;
#         left: 50px;
#         z-index:9999;
#         font-size:14px;
#         background-color: white;
#         padding: 10px;
#         border: 2px solid grey;
#         border-radius: 4px;
#         opacity: 0.9;
#         &quot;&gt;
#         &lt;b&gt;Missile Coverage&lt;/b&gt;&lt;br&gt;
#         &lt;span style=&quot;color:red;&quot;&gt;&amp;#9679;&lt;/span&gt; DF-11 (600 km)&lt;br&gt;&lt;span style=&quot;color:orange;&quot;&gt;&amp;#9679;&lt;/span&gt; DF-15 (725 km)&lt;br&gt;&lt;span style=&quot;color:#ff8800;&quot;&gt;&amp;#9679;&lt;/span&gt; DF-16B (700 km)&lt;br&gt;&lt;span style=&quot;color:#ff6600;&quot;&gt;&amp;#9679;&lt;/span&gt; DF-16 (1000 km)&lt;br&gt;&lt;span style=&quot;color:purple;&quot;&gt;&amp;#9679;&lt;/span&gt; DF-17 (2500 km)&lt;br&gt;&lt;span style=&quot;color:blue;&quot;&gt;&amp;#9679;&lt;/span&gt; DF-21A (1750 km)&lt;br&gt;&lt;span style=&quot;color:navy;&quot;&gt;&amp;#9679;&lt;/span&gt; DF-21D (1500 km)&lt;br&gt;&lt;span style=&quot;color:green;&quot;&gt;&amp;#9679;&lt;/span&gt; DF-26 (3000 km)&lt;br&gt;&lt;span style=&quot;color:pink;&quot;&gt;&amp;#9679;&lt;/span&gt; DF-100 (2000 km)&lt;br&gt;&lt;span style=&quot;color:#cc99ff;&quot;&gt;&amp;#9679;&lt;/span&gt; DF-10 (1500 km)&lt;br&gt;&lt;span style=&quot;color:#b266ff;&quot;&gt;&amp;#9679;&lt;/span&gt; DF-10A (1500 km)&lt;br&gt;&lt;span style=&quot;color:#4444cc;&quot;&gt;&amp;#9679;&lt;/span&gt; DF-31 (7000 km)&lt;br&gt;&lt;span style=&quot;color:#333399;&quot;&gt;&amp;#9679;&lt;/span&gt; DF-31A (11000 km)&lt;br&gt;&lt;span style=&quot;color:#191970;&quot;&gt;&amp;#9679;&lt;/span&gt; DF-31AG (11000 km)&lt;br&gt;&lt;span style=&quot;color:#2e8b57;&quot;&gt;&amp;#9679;&lt;/span&gt; DF-41 (13000 km)&lt;br&gt;&lt;span style=&quot;color:#8b0000;&quot;&gt;&amp;#9679;&lt;/span&gt; DF-5 (12000 km)
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe909c7217555fd57dc5800c83930cc2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe909c7217555fd57dc5800c83930cc2 = L.map(
#                 &quot;map_fe909c7217555fd57dc5800c83930cc2&quot;,
#                 {
#                     center: [30.0, 115.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_399c2731c4e4f115eb05909292be9195 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_399c2731c4e4f115eb05909292be9195.addTo(map_fe909c7217555fd57dc5800c83930cc2);
#
#
#             var feature_group_e3c56a744ca152e22ce73755362991a2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0ac2bd4c82bb42ac000d6ea21545dba6 = L.marker(
#                 [26.06142, 117.314914],
#                 {
# }
#             ).addTo(feature_group_e3c56a744ca152e22ce73755362991a2);
#
#
#         var popup_9fe6153ad3c76a79f2bc6cfa012793e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d7e76344fe47cde0fd71fce97aacc91 = $(`&lt;div id=&quot;html_8d7e76344fe47cde0fd71fce97aacc91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brigade 614 - Yong&#x27;an (Fujian) - DF-11 SRBM (300 km)&lt;/div&gt;`)[0];
#                 popup_9fe6153ad3c76a79f2bc6cfa012793e3.setContent(html_8d7e76344fe47cde0fd71fce97aacc91);
#
#
#
#         marker_0ac2bd4c82bb42ac000d6ea21545dba6.bindPopup(popup_9fe6153ad3c76a79f2bc6cfa012793e3)
#         ;
#
#
#
#
#             marker_0ac2bd4c82bb42ac000d6ea21545dba6.bindTooltip(
#                 `&lt;div&gt;
#                      Brigade 614 - Yong&#x27;an (Fujian)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_bf5682396f4e4c5f8981b3a3545b7554 = L.circle(
#                 [26.06142, 117.314914],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.09, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 600000, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(feature_group_e3c56a744ca152e22ce73755362991a2);
